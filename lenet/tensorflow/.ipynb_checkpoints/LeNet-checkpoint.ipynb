# %%
# -*- coding:utf-8 -*-  

from sys import path
import time
import numpy as np
import tensorflow as tf
import extract_mnist

# Parameter
batch_size = 64

#初始化单个卷积核上的参数
def weight_variable(shape):
	initial = tf.truncated_normal(shape, stddev=0.1)
	return tf.Variable(initial)

#初始化单个卷积核上的偏置值
def bias_variable(shape):
	initial = tf.constant(0.1, shape=shape)
	return tf.Variable(initial)

#输入特征x，用卷积核W进行卷积运算，strides为卷积核移动步长，
#padding表示是否需要补齐边缘像素使输出图像大小不变
def conv2d(x, W):
	return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

#对x进行最大池化操作，ksize进行池化的范围，
def max_pool_2x2(x):
	return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')

# average pooling
def avg_pool_2x2(x):
	return tf.nn.avg_pool(x, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')

def input_poisson(x_image, level):
	#print x_image
	x_image = (x_image+0.5) * level
	
	w = x_image.shape[0]
	h = x_image.shape[1]
	img = np.random.poisson(x_image, (w, h))
	#img = x_image
	img = img / level
	#print img
	return img

def main():
	
	#定义会话
	sess = tf.InteractiveSession()
	
	#声明输入图片数据，类别
	x = tf.placeholder('float',[None,784])
	y_ = tf.placeholder('float',[None,10])
	#输入图片数据转化
	x_image = tf.reshape(x,[-1,28,28,1])

	#第一层卷积层，初始化卷积核参数、偏置值，该卷积层5*5大小，一个通道，共有32个不同卷积核
	#[filter_height, filter_width, in_channels, out_channels]
	W_conv1 = weight_variable([5, 5, 1, 20])
	b_conv1 = bias_variable([20])
	#进行卷积操作，并添加relu激活函数
	#h_conv1 = tf.nn.relu(conv2d(x_image,W_conv1) + b_conv1)
	h_conv1 = tf.nn.relu(conv2d(x_image,W_conv1)) #withoutbias
	#进行最大池化
	h_pool1 = avg_pool_2x2(h_conv1)

	#同理第二层卷积层
	W_conv2 = weight_variable([5,5,20,50])
	b_conv2 = bias_variable([50])
	#h_conv2 = tf.nn.relu(conv2d(h_pool1,W_conv2) + b_conv2)
	h_conv2 = tf.nn.relu(conv2d(h_pool1,W_conv2))
	h_pool2 = avg_pool_2x2(h_conv2)
	
	#全连接层
	#权值参数
	W_fc1 = weight_variable([7*7*50,500])
	#偏置值
	b_fc1 = bias_variable([500])
	#将卷积的产出展开
	h_pool2_flat = tf.reshape(h_pool2,[-1,7*7*50])
	#神经网络计算，并添加relu激活函数
	#h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat,W_fc1) + b_fc1)
	h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat,W_fc1))
	
	#Dropout层，可控制是否有一定几率的神经元失效，防止过拟合，训练时使用，测试时不使用
	keep_prob = tf.placeholder("float")
	#Dropout计算
	h_fc1_drop = tf.nn.dropout(h_fc1,keep_prob)
	
	#输出层，使用softmax进行多分类
	W_fc2 = weight_variable([500,10])
	b_fc2 = bias_variable([10])
	#y_conv=tf.maximum(tf.nn.softmax(tf.matmul(h_fc1_drop, W_fc2) + b_fc2),1e-30)
	y_conv=tf.maximum(tf.nn.softmax(tf.matmul(h_fc1_drop, W_fc2)),1e-30)

	#代价函数
	cross_entropy = -tf.reduce_sum(y_*tf.log(y_conv))
	#使用Adam优化算法来调整参数
	train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
	
	#测试正确率
	correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
	accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
	
	#保存参数
	saver = tf.train.Saver()

	#所有变量进行初始化
	sess.run(tf.initialize_all_variables())

	#获取mnist数据
	mnist_data_set = extract_mnist.MnistDataSet('../mnist/')
	te_images,test_labels = mnist_data_set.test_data()
	#test_images = input_poisson(te_images)
	test_images = te_images + 0.5
	#进行训练
	start_time = time.time()
	for i in xrange(20000):
	#for i in xrange(1):
		#获取训练数据
		xs, batch_ys = mnist_data_set.next_train_batch(batch_size)
		batch_xs = input_poisson(xs, 50.0)
		#print batch_xs.shape[0]
		#每迭代100个 batch，对当前训练数据进行测试，输出当前预测准确率
		if i%100 == 0:
			train_accuracy = accuracy.eval(feed_dict={x:batch_xs, y_: batch_ys, keep_prob: 1.0})
			print "step %d, training accuracy %g"%(i, train_accuracy)
			#计算间隔时间
			end_time = time.time()
			print 'time: ',(end_time - start_time)
			start_time = end_time
		#训练数据
		train_step.run(feed_dict={x: batch_xs, y_: batch_ys, keep_prob: 0.5})

	
	#保存参数
	if not tf.gfile.Exists('model_data'):
		tf.gfile.MakeDirs('model_data')
	save_path = saver.save(sess, "model_data/model.ckpt")
	print "Model saved in file: ", save_path

	#输出整体测试数据的情况
	avg = 0
	for i in xrange(200):
		avg+=accuracy.eval(feed_dict={x: test_images[i*50:i*50+50], y_: test_labels[i*50:i*50+50], keep_prob: 1.0})
	avg/=200
	print "test accuracy %g"%avg

	#关闭会话
	sess.close()


if __name__ == '__main__':
	main()
# Out:
# WARNING:tensorflow:From <ipython-input-3-1e5d7ffd6c14>:110: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# step 0, training accuracy 0.03125
# time:  0.0132279396057
# step 100, training accuracy 0.84375
# time:  0.528229951859
# step 200, training accuracy 0.890625
# time:  0.480327129364
# step 300, training accuracy 0.90625
# time:  0.479723930359
# step 400, training accuracy 0.90625
# time:  0.477215051651
# step 500, training accuracy 0.890625
# time:  0.475703001022
# step 600, training accuracy 0.953125
# time:  0.477452039719
# step 700, training accuracy 0.890625
# time:  0.499322891235
# step 800, training accuracy 0.953125
# time:  0.508769989014
# step 900, training accuracy 0.9375
# time:  0.521117925644
# step 1000, training accuracy 0.9375
# time:  0.505483150482
# step 1100, training accuracy 0.9375
# time:  0.475792884827
# step 1200, training accuracy 0.953125
# time:  0.47519493103
# step 1300, training accuracy 1
# time:  0.482039213181
# step 1400, training accuracy 0.9375
# time:  0.489976882935
# step 1500, training accuracy 0.984375
# time:  0.516752004623
# step 1600, training accuracy 0.984375
# time:  0.477973937988
# step 1700, training accuracy 1
# time:  0.476988077164
# step 1800, training accuracy 0.9375
# time:  0.478501081467
# step 1900, training accuracy 0.953125
# time:  0.505010843277
# step 2000, training accuracy 0.9375
# time:  0.513729095459
# step 2100, training accuracy 0.984375
# time:  0.478400945663
# step 2200, training accuracy 1
# time:  0.516008138657
# step 2300, training accuracy 0.9375
# time:  0.494004964828
# step 2400, training accuracy 0.984375
# time:  0.475021839142
# step 2500, training accuracy 0.984375
# time:  0.486909151077
# step 2600, training accuracy 0.96875
# time:  0.507364988327
# step 2700, training accuracy 0.96875
# time:  0.475992918015
# step 2800, training accuracy 1
# time:  0.477033138275
# step 2900, training accuracy 0.984375
# time:  0.506557941437
# step 3000, training accuracy 1
# time:  0.527559995651
# step 3100, training accuracy 0.9375
# time:  0.475982904434
# step 3200, training accuracy 0.984375
# time:  0.473782062531
# step 3300, training accuracy 0.9375
# time:  0.4786028862
# step 3400, training accuracy 1
# time:  0.522560119629
# step 3500, training accuracy 0.984375
# time:  0.484209060669
# step 3600, training accuracy 0.96875
# time:  0.487215995789
# step 3700, training accuracy 0.984375
# time:  0.486585855484
# step 3800, training accuracy 1
# time:  0.552925109863
# step 3900, training accuracy 0.96875
# time:  0.47931599617
# step 4000, training accuracy 0.9375
# time:  0.484212875366
# step 4100, training accuracy 0.96875
# time:  0.525124073029
# step 4200, training accuracy 0.96875
# time:  0.479176044464
# step 4300, training accuracy 0.953125
# time:  0.476160049438
# step 4400, training accuracy 0.96875
# time:  0.515697002411
# step 4500, training accuracy 0.984375
# time:  0.480124950409
# step 4600, training accuracy 0.96875
# time:  0.477364063263
# step 4700, training accuracy 0.96875
# time:  0.513303995132
# step 4800, training accuracy 1
# time:  0.511854887009
# step 4900, training accuracy 1
# time:  0.475878000259
# step 5000, training accuracy 0.96875
# time:  0.507297992706
# step 5100, training accuracy 0.984375
# time:  0.518217086792
# step 5200, training accuracy 0.96875
# time:  0.509032011032
# step 5300, training accuracy 1
# time:  0.516435861588
# step 5400, training accuracy 0.984375
# time:  0.490601062775
# step 5500, training accuracy 0.984375
# time:  0.495233058929
# step 5600, training accuracy 0.96875
# time:  0.490355014801
# step 5700, training accuracy 0.984375
# time:  0.506618022919
# step 5800, training accuracy 0.984375
# time:  0.507408857346
# step 5900, training accuracy 1
# time:  0.4983689785
# step 6000, training accuracy 1
# time:  0.503089189529
# step 6100, training accuracy 1
# time:  0.502157926559
# step 6200, training accuracy 1
# time:  0.505872011185
# step 6300, training accuracy 1
# time:  0.504251003265
# step 6400, training accuracy 1
# time:  0.500062942505
# step 6500, training accuracy 0.984375
# time:  0.478209018707
# step 6600, training accuracy 1
# time:  0.513043880463
# step 6700, training accuracy 1
# time:  0.479297161102
# step 6800, training accuracy 0.984375
# time:  0.480762958527
# step 6900, training accuracy 1
# time:  0.478152990341
# step 7000, training accuracy 0.96875
# time:  0.489356040955
# step 7100, training accuracy 0.984375
# time:  0.480669021606
# step 7200, training accuracy 1
# time:  0.475630044937
# step 7300, training accuracy 1
# time:  0.479593992233
# step 7400, training accuracy 1
# time:  0.483995914459
# step 7500, training accuracy 1
# time:  0.509711027145
# step 7600, training accuracy 0.96875
# time:  0.492342948914
# step 7700, training accuracy 1
# time:  0.480536937714
# step 7800, training accuracy 0.984375
# time:  0.480748176575
# step 7900, training accuracy 1
# time:  0.49035692215
# step 8000, training accuracy 0.953125
# time:  0.492187976837
# step 8100, training accuracy 0.96875
# time:  0.484814882278
# step 8200, training accuracy 0.984375
# time:  0.488287210464
# step 8300, training accuracy 0.984375
# time:  0.485478878021
# step 8400, training accuracy 1
# time:  0.488760948181
# step 8500, training accuracy 1
# time:  0.512814998627
# step 8600, training accuracy 1
# time:  0.490000963211
# step 8700, training accuracy 0.96875
# time:  0.485606193542
# step 8800, training accuracy 0.984375
# time:  0.49408698082
# step 8900, training accuracy 1
# time:  0.488219022751
# step 9000, training accuracy 1
# time:  0.483994960785
# step 9100, training accuracy 0.984375
# time:  0.492261886597
# step 9200, training accuracy 1
# time:  0.495527982712
# step 9300, training accuracy 0.984375
# time:  0.489485025406
# step 9400, training accuracy 0.984375
# time:  0.514413118362
# step 9500, training accuracy 1
# time:  0.49785900116
# step 9600, training accuracy 0.984375
# time:  0.487046003342
# step 9700, training accuracy 0.984375
# time:  0.489176988602
# step 9800, training accuracy 0.984375
# time:  0.498237848282
# step 9900, training accuracy 0.984375
# time:  0.492605209351
# step 10000, training accuracy 1
# time:  0.486015796661
# step 10100, training accuracy 0.953125
# time:  0.488453149796
# step 10200, training accuracy 0.984375
# time:  0.490195989609
# step 10300, training accuracy 0.984375
# time:  0.485071897507
# step 10400, training accuracy 1
# time:  0.520173072815
# step 10500, training accuracy 1
# time:  0.484341859818
# step 10600, training accuracy 1
# time:  0.484959125519
# step 10700, training accuracy 1
# time:  0.480876922607
# step 10800, training accuracy 1
# time:  0.476271152496
# step 10900, training accuracy 1
# time:  0.488492012024
# step 11000, training accuracy 0.984375
# time:  0.481056928635
# step 11100, training accuracy 1
# time:  0.478389978409
# step 11200, training accuracy 0.96875
# time:  0.481920957565
# step 11300, training accuracy 1
# time:  0.504630088806
# step 11400, training accuracy 1
# time:  0.479431867599
# step 11500, training accuracy 1
# time:  0.498255968094
# step 11600, training accuracy 0.984375
# time:  0.481337070465
# step 11700, training accuracy 1
# time:  0.478753089905
# step 11800, training accuracy 0.984375
# time:  0.477010965347
# step 11900, training accuracy 1
# time:  0.476937055588
# step 12000, training accuracy 1
# time:  0.482651948929
# step 12100, training accuracy 1
# time:  0.500709056854
# step 12200, training accuracy 1
# time:  0.509305953979
# step 12300, training accuracy 1
# time:  0.478403091431
# step 12400, training accuracy 1
# time:  0.490895986557
# step 12500, training accuracy 1
# time:  0.487401008606
# step 12600, training accuracy 1
# time:  0.481199979782
# step 12700, training accuracy 1
# time:  0.483295917511
# step 12800, training accuracy 1
# time:  0.482343912125
# step 12900, training accuracy 1
# time:  0.476701021194
# step 13000, training accuracy 1
# time:  0.477344036102
# step 13100, training accuracy 1
# time:  0.477586984634
# step 13200, training accuracy 1
# time:  0.524254083633
# step 13300, training accuracy 1
# time:  0.478855848312
# step 13400, training accuracy 1
# time:  0.478025197983
# step 13500, training accuracy 1
# time:  0.475583791733
# step 13600, training accuracy 1
# time:  0.479341030121
# step 13700, training accuracy 1
# time:  0.481857061386
# step 13800, training accuracy 1
# time:  0.484699010849
# step 13900, training accuracy 0.984375
# time:  0.482284069061
# step 14000, training accuracy 1
# time:  0.50078701973
# step 14100, training accuracy 1
# time:  0.510371923447
# step 14200, training accuracy 0.984375
# time:  0.482857942581
# step 14300, training accuracy 1
# time:  0.48312997818
# step 14400, training accuracy 1
# time:  0.486591100693
# step 14500, training accuracy 1
# time:  0.4864590168
# step 14600, training accuracy 0.984375
# time:  0.481745958328
# step 14700, training accuracy 1
# time:  0.521482944489
# step 14800, training accuracy 1
# time:  0.514903068542
# step 14900, training accuracy 0.984375
# time:  0.483918905258
# step 15000, training accuracy 1
# time:  0.504739046097
# step 15100, training accuracy 1
# time:  0.489833116531
# step 15200, training accuracy 0.984375
# time:  0.480094909668
# step 15300, training accuracy 1
# time:  0.481875896454
# step 15400, training accuracy 1
# time:  0.480795145035
# step 15500, training accuracy 0.984375
# time:  0.476001977921
# step 15600, training accuracy 1
# time:  0.477375984192
# step 15700, training accuracy 0.96875
# time:  0.478964090347
# step 15800, training accuracy 1
# time:  0.481169939041
# step 15900, training accuracy 1
# time:  0.480288982391
# step 16000, training accuracy 1
# time:  0.507925033569
# step 16100, training accuracy 0.96875
# time:  0.478891849518
# step 16200, training accuracy 1
# time:  0.48125910759
# step 16300, training accuracy 1
# time:  0.479335069656
# step 16400, training accuracy 1
# time:  0.482445955276
# step 16500, training accuracy 0.984375
# time:  0.479197025299
# step 16600, training accuracy 0.984375
# time:  0.481698989868
# step 16700, training accuracy 0.984375
# time:  0.479507923126
# step 16800, training accuracy 1
# time:  0.477391958237
# step 16900, training accuracy 0.984375
# time:  0.506865978241
# step 17000, training accuracy 1
# time:  0.480763196945
# step 17100, training accuracy 1
# time:  0.477902889252
# step 17200, training accuracy 0.984375
# time:  0.489320993423
# step 17300, training accuracy 1
# time:  0.482547044754
# step 17400, training accuracy 1
# time:  0.480241060257
# step 17500, training accuracy 1
# time:  0.486958026886
# step 17600, training accuracy 0.953125
# time:  0.478491783142
# step 17700, training accuracy 1
# time:  0.481988191605
# step 17800, training accuracy 1
# time:  0.490999937057
# step 17900, training accuracy 1
# time:  0.511375904083
# step 18000, training accuracy 0.984375
# time:  0.488337993622
# step 18100, training accuracy 1
# time:  0.489716053009
# step 18200, training accuracy 1
# time:  0.491498947144
# step 18300, training accuracy 0.96875
# time:  0.491683006287
# step 18400, training accuracy 1
# time:  0.485757112503
# step 18500, training accuracy 1
# time:  0.478584051132
# step 18600, training accuracy 1
# time:  0.479482889175
# step 18700, training accuracy 1
# time:  0.485782146454
# step 18800, training accuracy 1
# time:  0.509583950043
# step 18900, training accuracy 0.984375
# time:  0.478653907776
# step 19000, training accuracy 1
# time:  0.478517055511
# step 19100, training accuracy 1
# time:  0.486173868179
# step 19200, training accuracy 1
# time:  0.481610059738
# step 19300, training accuracy 1
# time:  0.48234796524
# step 19400, training accuracy 1
# time:  0.484275102615
# step 19500, training accuracy 1
# time:  0.487990856171
# step 19600, training accuracy 1
# time:  0.483946084976
# step 19700, training accuracy 1
# time:  0.524444103241
# step 19800, training accuracy 0.984375
# time:  0.48922085762
# step 19900, training accuracy 0.984375
# time:  0.495141983032
# Model saved in file:  model_data/model.ckpt
# test accuracy 0.9919

# %%
# -*- coding:utf-8 -*-  

from sys import path
import time
import numpy as np
import tensorflow as tf
import extract_mnist
